# %%
import pandas as pd
import requests

# %%
# LAGT (v1.0.1) dataset directly from Zenodo
resp = requests.get("https://zenodo.org/record/4971946/files/LAGT_v1-0.json?download=1")
LAGT = pd.DataFrame(resp.json())

# %%
LAGT.columns
# Out:
# Index(['filename', 'author', 'title', 'wordcount', 'author_id', 'doc_id',
#        'raw_date', 'date_avr', 'date_probs', 'date_manual', 'provenience',
#        'tlg_epithet', 'clean_string', 'n_sentences', 'lemmatized_sentences'],
#       dtype='object')

# %%
len(LAGT[LAGT["provenience"]=="christian"])
# Out:
# 148

# %%
LAGT_metadata = pd.read_csv("../data/LAGT_metadata.csv")
provenience_dict = dict(zip(LAGT_metadata["filename"],  LAGT_metadata["provenience"]))
author_dict = dict(zip(LAGT_metadata["author_id"],  LAGT_metadata["author"]))
LAGT["provenience"] = LAGT["filename"].apply(lambda x: provenience_dict[x])

# %%
len(LAGT[LAGT["provenience"]=="christian"])
# Out:
# 216

# %%
LAGT[(LAGT["provenience"]=="christian") & (LAGT["date_avr"].isnull())]
# Out:
#                            filename                                  author  \
# 1194  tlg1750.tlg001.1st1K-grc1.xml    Pseudo-Dorotheus (Vitae Prophetarum)
# 1195  tlg1750.tlg002.1st1K-grc1.xml                       Vitae Prophetarum
# 1196  tlg1750.tlg003.1st1K-grc1.xml  Vitae Prophetarum (Scholius Hesychius)
# 1197  tlg1750.tlg004.1st1K-grc1.xml    Pseudo-Dorotheus (Vitae Prophetarum)
#
#                                                   title  wordcount author_id  \
# 1194   De prophetarum vita et obitu (Dorothei recensio)       5347   tlg1750
# 1195    De prophetarum vita et obitu (recensio anonyma)       4110   tlg1750
# 1196  De prophetarum vita et obitu (recensio scholii...       1166   tlg1750
# 1197           Index apostolorum discipulorumque Domini       3616   tlg1750
#
#               doc_id raw_date  date_avr date_probs  date_manual provenience  \
# 1194  tlg1750.tlg001    Varia       NaN         {}          NaN   christian
# 1195  tlg1750.tlg002    Varia       NaN         {}          NaN   christian
# 1196  tlg1750.tlg003    Varia       NaN         {}          NaN   christian
# 1197  tlg1750.tlg004    Varia       NaN         {}          NaN   christian
#
#      tlg_epithet                                       clean_string  \
# 1194          []  Οὗτος Ὠσηὲ τῶν ιβʹ προφητῶν ὁ πρῶτος, ἀξιωθεὶς...
# 1195          []  αʹ. Ἡσαΐας ἀπὸ Ἱερουσαλὴμ θνήσκει ὑπὸ Μανασσῆ ...
# 1196          []  αʹ. Ὠσηὲ ἑρμηνεύεται σωζόμενος. Οὗτος ἦν ἐκ ελ...
# 1197          []  Δωροθέου ἐπισκόπου Τύρου ἀρχαίου ἀνδρὸς πνευμα...
#
#       n_sentences                               lemmatized_sentences
# 1194          329  [[ὠσηὲ, προφήτης, πρῶτος, ἀξιωθεὶς, λέγω, δεσπ...
# 1195          329  [[], [Ἠσαΐας, Ἱεροσόλυμα, θνήσκω, Μανασσῆς, πρ...
# 1196          105  [[], [ὠσηὲ, ἑρμηνεύω, σωζόμενος], [ελεμὼθ, φυλ...
# 1197          253  [[δωροθέου, ἐπίσκοπος, Τύρος, ἀρχαῖος, ἀνήρ, π...

# %%
LAGT = LAGT[LAGT["date_avr"] < 5]

# %%
LAGT[LAGT["doc_id"].str.startswith("tlg0031.tlg006")]
# Out:
#                             filename          author                   title  \
# 390  tlg0031.tlg006.perseus-grc2.xml  Paul of Tarsus  New Testament - Romans
#
#      wordcount    author_id          doc_id raw_date  date_avr  date_probs  \
# 390       7107  tlg0031paul  tlg0031.tlg006   A.D. 1       0.5  {'0.5': 1}
#
#      date_manual provenience tlg_epithet  \
# 390          0.5   christian          []
#
#                                           clean_string  n_sentences  \
# 390   ΠΑΥΛΟΣ δοῦλος Ἰησοῦ Χριστοῦ, κλητὸς ἀπόστολος...          490
#
#                                   lemmatized_sentences  \
# 390  [[Παῦλος, δοῦλος, Ἰησοῦς, Χριστός, κλητός, ἀπό...
#
#                                         sentences_paul  sentences_paul_N
# 390  [[Παῦλος, δοῦλος, Ἰησοῦς, Χριστός, κλητός, ἀπό...                 1

# %%
LAGT[LAGT["author_id"].str.startswith("tlg0031paul")]
# Out:
#                             filename          author  \
# 390  tlg0031.tlg006.perseus-grc2.xml  Paul of Tarsus
# 391  tlg0031.tlg007.perseus-grc2.xml  Paul of Tarsus
# 392  tlg0031.tlg008.perseus-grc2.xml  Paul of Tarsus
# 393  tlg0031.tlg009.perseus-grc2.xml  Paul of Tarsus
# 395  tlg0031.tlg011.perseus-grc2.xml  Paul of Tarsus
# 397  tlg0031.tlg013.perseus-grc2.xml  Paul of Tarsus
# 402  tlg0031.tlg018.perseus-grc2.xml  Paul of Tarsus
#
#                                title  wordcount    author_id          doc_id  \
# 390           New Testament - Romans       7107  tlg0031paul  tlg0031.tlg006
# 391    New Testament - 1 Corinthians       6814  tlg0031paul  tlg0031.tlg007
# 392    New Testament - 2 Corinthians       4470  tlg0031paul  tlg0031.tlg008
# 393        New Testament - Galatians       2235  tlg0031paul  tlg0031.tlg009
# 395      New Testament - Philippians       1631  tlg0031paul  tlg0031.tlg011
# 397  New Testament - 1 Thessalonians       1475  tlg0031paul  tlg0031.tlg013
# 402         New Testament - Philemon        334  tlg0031paul  tlg0031.tlg018
#
#     raw_date  date_avr  date_probs  date_manual provenience tlg_epithet  \
# 390   A.D. 1       0.5  {'0.5': 1}          0.5   christian          []
# 391   A.D. 1       0.5  {'0.5': 1}          0.5   christian          []
# 392   A.D. 1       0.5  {'0.5': 1}          0.5   christian          []
# 393   A.D. 1       0.5  {'0.5': 1}          0.5   christian          []
# 395   A.D. 1       0.5  {'0.5': 1}          0.5   christian          []
# 397   A.D. 1       0.5  {'0.5': 1}          0.5   christian          []
# 402   A.D. 1       0.5  {'0.5': 1}          0.5   christian          []
#
#                                           clean_string  n_sentences  \
# 390   ΠΑΥΛΟΣ δοῦλος Ἰησοῦ Χριστοῦ, κλητὸς ἀπόστολος...          490
# 391   ΠΑΥΛΟΣ κλητὸς ἀπόστολος Ἰησοῦ Χριστοῦ διὰ θελ...          544
# 392   ΠΑΥΛΟΣ ἀπόστολος Χριστοῦ Ἰησοῦ διὰ θελήματος ...          274
# 393   ΠΑΥΛΟΣ ἀπόστολος, οὐκ ἀπʼ ἀνθρώπων οὐδὲ διʼ ἀ...          159
# 395   ΠΑΥΛΟΣ ΚΑΙ ΤΙΜΟΘΕΟΣ δοῦλοι Χριστοῦ Ἰησοῦ πᾶσι...           83
# 397   ΠΑΥΛΟΣ ΚΑΙ ΣΙΛΟΥΑΝΟΣ ΚΑΙ ΤΙΜΟΘΕΟΣ τῇ ἐκκλησίᾳ...           65
# 402   ΠΑΥΛΟΣ δέσμιος Χριστοῦ Ἰησοῦ καὶ Τιμόθεος ὁ ἀ...           17
#
#                                   lemmatized_sentences
# 390  [[Παῦλος, δοῦλος, Ἰησοῦς, Χριστός, κλητός, ἀπό...
# 391  [[Παῦλος, κλητός, ἀπόστολος, Ἰησοῦς, Χριστός, ...
# 392  [[Παῦλος, ἀπόστολος, Χριστός, Ἰησοῦς, θέλημα, ...
# 393  [[Παῦλος, ἀπόστολος, ἄνθρωπος, ἄνθρωπος, Ἰησοῦ...
# 395  [[Παῦλος, Τιμόθεος, δοῦλος, Χριστός, Ἰησοῦς, ἅ...
# 397  [[Παῦλος, σιλουανος, Τιμόθεος, ἐκκλησία, Θεσσα...
# 402  [[Παῦλος, δέσμιος, Χριστός, Ἰησοῦς, Τιμόθεος, ...

# %%
def get_word_sentences(sentences_list, word):
    selected_sentences = [sentence for sentence in sentences_list if word in sentence]
    return selected_sentences

# %%
word = "Παῦλος"
LAGT["sentences_paul"] = LAGT["lemmatized_sentences"].apply(lambda x: get_word_sentences(x, word))

# %%
LAGT["sentences_paul_N"] = LAGT["sentences_paul"].apply(lambda x: len(x))

# %%
# how many documents contain the word "Παῦλος"
len(LAGT[LAGT["sentences_paul_N"]>0])
# Out:
# 121

# %%
LAGT["sentences_paul_N"].sum()
# Out:
# 1138

# %%
LAGT[LAGT["provenience"]=="christian"]["sentences_paul_N"].sum()
# Out:
# 1045

# %%
LAGT[(LAGT["provenience"]=="christian") & (LAGT["author_id"]!="tlg0031paul")]["sentences_paul_N"].sum()
# Out:
# 1027

# %%
df = LAGT[(LAGT["provenience"]=="christian") &(LAGT["author_id"]!="tlg0031paul")]#  ["sentences_paul_N"].sum()

# %%
df_authors = df.groupby("author_id").sum()[["wordcount", "n_sentences", "sentences_paul_N"]].sort_values("sentences_paul_N", ascending=False)# 
def get_author(x):
    try:
        return author_dict[x]
    except:
        return None
df_authors.reset_index(inplace=True)
df_authors["author"] = df_authors["author_id"].apply(get_author) 
df_authors.set_index("author", inplace=True)
df_authors.head(20)
# Out:
#                                     author_id  wordcount  n_sentences  \
# author
# Origenes                              tlg2042     931431       110127
# Luke (the evangelist)             tlg0031luke      37864         2234
# Epiphanius                            tlg2021     325038        33079
# Socrates, Scholasticus                tlg2057     103901         8743
# Sozomenus, Salaminius Hermias         tlg2048     112966         7150
# Athanasius                            tlg2035      94010        10789
# Theodoret, Bishop of Cyrus            tlg4089     153333        16094
# Basil, Saint, Bishop of Caesarea      tlg2040     144429        11257
# Clement of Alexandria                 tlg0555     235754        14753
# Eusebius                              tlg2018     620546        35220
# pseudo-Menander                       tlg2022      77297        20005
# Irenaeus                              tlg1447      24651         4525
# Pauline literature                tlg0031pspa       8324          390
# Hippolytus                            tlg2115      69987         4394
# Polycarp                              tlg1622       1804          212
# Clemens Romanus                       tlg1271      13936         1410
# Dionysius Corinthius                  tlg1329        607           67
# Ignatius Antiochenus                  tlg1443       8396          790
# Marcus Diaconus                       tlg2806      24954         2132
# Philostorgius                         tlg2058      37002         4172
#
#                                   sentences_paul_N
# author
# Origenes                                       459
# Luke (the evangelist)                          125
# Epiphanius                                     102
# Socrates, Scholasticus                          76
# Sozomenus, Salaminius Hermias                   63
# Athanasius                                      49
# Theodoret, Bishop of Cyrus                      40
# Basil, Saint, Bishop of Caesarea                23
# Clement of Alexandria                           18
# Eusebius                                        17
# pseudo-Menander                                 14
# Irenaeus                                        12
# Pauline literature                              10
# Hippolytus                                       7
# Polycarp                                         2
# Clemens Romanus                                  2
# Dionysius Corinthius                             2
# Ignatius Antiochenus                             2
# Marcus Diaconus                                  1
# Philostorgius                                    1

# %%
df_authors["paul_proportion"] = df_authors["sentences_paul_N"] / df_authors["n_sentences"]
df_authors.sort_values("paul_proportion", ascending=False).head(20)
# Out:
#                                     author_id  wordcount  n_sentences  \
# author
# Luke (the evangelist)             tlg0031luke      37864         2234
# Dionysius Corinthius                  tlg1329        607           67
# Pauline literature                tlg0031pspa       8324          390
# NaN                                  tlg0031f       1095           42
# Polycarp                              tlg1622       1804          212
# Sozomenus, Salaminius Hermias         tlg2048     112966         7150
# Socrates, Scholasticus                tlg2057     103901         8743
# Seniores Apud Irenaeum                tlg1665        695          200
# Athanasius                            tlg2035      94010        10789
# Origenes                              tlg2042     931431       110127
# Epiphanius                            tlg2021     325038        33079
# Irenaeus                              tlg1447      24651         4525
# Ignatius Antiochenus                  tlg1443       8396          790
# Theodoret, Bishop of Cyrus            tlg4089     153333        16094
# Basil, Saint, Bishop of Caesarea      tlg2040     144429        11257
# Hippolytus                            tlg2115      69987         4394
# Clemens Romanus                       tlg1271      13936         1410
# Clement of Alexandria                 tlg0555     235754        14753
# pseudo-Menander                       tlg2022      77297        20005
# Eusebius                              tlg2018     620546        35220
#
#                                   sentences_paul_N  paul_proportion
# author
# Luke (the evangelist)                          125         0.055953
# Dionysius Corinthius                             2         0.029851
# Pauline literature                              10         0.025641
# NaN                                              1         0.023810
# Polycarp                                         2         0.009434
# Sozomenus, Salaminius Hermias                   63         0.008811
# Socrates, Scholasticus                          76         0.008693
# Seniores Apud Irenaeum                           1         0.005000
# Athanasius                                      49         0.004542
# Origenes                                       459         0.004168
# Epiphanius                                     102         0.003084
# Irenaeus                                        12         0.002652
# Ignatius Antiochenus                             2         0.002532
# Theodoret, Bishop of Cyrus                      40         0.002485
# Basil, Saint, Bishop of Caesarea                23         0.002043
# Hippolytus                                       7         0.001593
# Clemens Romanus                                  2         0.001418
# Clement of Alexandria                           18         0.001220
# pseudo-Menander                                 14         0.000700
# Eusebius                                        17         0.000483

# %%
df[df["author"].str.startswith(">Cate")]
# Out:
#                          filename                        author  \
# 1443  tlg4102.tlg034.opp-grc1.xml  >Catenae (Novum Testamentum)
#
#                                    title  wordcount author_id          doc_id  \
# 1443  Catena In Epistulam I Ad Timotheum      14122   tlg4102  tlg4102.tlg034
#
#        raw_date  date_avr                                         date_probs  \
# 1443  p. A.D. 5       6.0  {'14.5': 0.001, '13.5': 0.002, '12.5': 0.0039,...
#
#       date_manual provenience tlg_epithet  \
# 1443          NaN   christian          []
#
#                                            clean_string  n_sentences  \
# 1443  ΤΩΝ τοῦ Ἀποστόλου μαθητῶν ὁ Τιμόθεος ἦν· καὶ μ...         1157
#
#                                    lemmatized_sentences  \
# 1443  [[ἀπόστολος, μαθητής, Τιμόθεος, εἰμί], [μαρτυρ...
#
#                                          sentences_paul  sentences_paul_N
# 1443  [[συνετός, εἰμί, ἀκούω, Παῦλος, περιτομή, κηρύ...                36
